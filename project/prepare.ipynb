# %%
import albumentations as A
import cv2
from glob import glob
import os
from uuid import uuid4
import random
import math
import shutil
import numpy as np

old_images_path = "./datasets/old-images"
old_bboxes_path = "./datasets/old-bboxes"

final_dataset_path = "./datasets/final"

augmentations_count = 5
# Out:
# c:\Users\Eugene\AppData\Local\Programs\Python\Python311\Lib\site-packages\albumentations\__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
transform = A.Compose([
  A.HorizontalFlip(),
  A.RandomBrightnessContrast(0.2, 0.2),
  A.Rotate((10, 10)),
  A.GaussNoise(p=0.1),
  A.Blur(p=0.3),
  A.HueSaturationValue(p=0.1),
  A.Resize(640, 640, cv2.INTER_LANCZOS4, cv2.INTER_LANCZOS4)
], bbox_params=A.BboxParams(format="yolo"))

# %%
os.makedirs(final_dataset_path, exist_ok=True)
dataset_subsets_names = ["train", "val", "test"]
dataset_subsets_ratio = [0.7, 0.2, 0.1]

for name in dataset_subsets_names:
  os.makedirs(os.path.join(final_dataset_path, "images", name), exist_ok=True)
  os.makedirs(os.path.join(final_dataset_path, "labels", name), exist_ok=True)

missed_count = 0
processed_count = 0

subsets_images_count = {
  "train": 0,
  "val": 0,
  "test": 0
}

images_paths = glob(os.path.join(old_images_path, "*.PNG"))
random.shuffle(images_paths)

for image_path in images_paths:
  img = cv2.imread(image_path)
  
  bbox_path = os.path.join(old_bboxes_path, os.path.basename(image_path).replace(".PNG", ".txt"))
  
  bboxes = []
  class_labels = []
  try:
    with open(bbox_path, "r") as file:
      for line in file:
        cols = line.strip().split()
        class_labels.append(int(cols[0]))
        bboxes.append(np.array(list(map(lambda x: max(float(x), 0), cols[1:]))))
  except:
    print(f"Missed {image_path} because it has no bboxes")
    missed_count += 1
    continue
  
  subset = dataset_subsets_ratio[0]
  p = random.random()
  a = 0
  for i in range(len(dataset_subsets_ratio)):
    a += dataset_subsets_ratio[i]
    if (p < a):
      subset = dataset_subsets_names[i]
      break

  try:
    for _ in range(augmentations_count):
      aug_result = transform(image=img, bboxes=bboxes, class_labels=class_labels)
      aug_image = aug_result["image"]
      aug_bboxes = aug_result["bboxes"]
      
      uuid = uuid4().hex
      
      cv2.imwrite(os.path.join(final_dataset_path, "images", subset, f"{uuid}.PNG"), aug_image)
      
      with open(os.path.join(final_dataset_path, "labels", subset, f"{uuid}.txt"), "w") as file:
        for bbox, class_id in zip(aug_bboxes, class_labels):
          file.write(f"{class_id} {' '.join(map(str, bbox))}\n")
      subsets_images_count[subset] += 1
  except Exception as e:
    print(f"Error creating bboxes {image_path}: {e}")
    missed_count += 1
    continue
    
  processed_count += 1
  
print(f"Processed {processed_count} images, missed {missed_count} images")
print(f"Train: {subsets_images_count['train']}\nVal: {subsets_images_count['val']}\nTest: {subsets_images_count['test']}")
# Out:
# Missed ./datasets/old-images\frame_000432.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001104.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000400.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000399.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000427.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000483.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001099.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001097.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000425.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000406.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000421.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000472.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000484.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000475.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000486.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000443.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000460.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000431.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000424.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000470.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000393.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000409.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000440.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000455.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000391.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000445.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000438.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000423.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000429.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000488.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000452.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000463.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000434.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000479.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000446.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000461.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000464.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000436.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000422.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000398.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001098.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000477.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001103.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000474.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000454.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000478.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000408.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000451.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000394.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000401.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000459.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001102.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000396.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000485.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000437.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000417.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000416.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000453.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000397.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000466.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000448.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000447.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000458.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000473.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000413.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000395.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000444.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000469.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000439.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000410.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000489.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000462.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001096.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000411.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000402.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000415.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000418.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001100.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000419.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000441.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000487.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000450.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000468.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000465.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000430.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000476.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_001101.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000449.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000426.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000480.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000403.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000471.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000407.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000482.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000404.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000414.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000435.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000457.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000392.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000428.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000442.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000433.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000467.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000456.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000412.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000405.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000481.PNG because it has no bboxes
# Missed ./datasets/old-images\frame_000420.PNG because it has no bboxes
# Processed 1789 images, missed 108 images
# Train: 6335
# Val: 1810
# Test: 800
