# %%
import albumentations as A
import cv2
from glob import glob
import os
from uuid import uuid4
import random
import math
import shutil
import numpy as np

old_images_path = "./datasets/old-images"
old_bboxes_path = "./datasets/old-bboxes"

final_dataset_path = "./datasets/final"

augmentations_count = 5
# Out:
# c:\Users\Eugene\AppData\Local\Programs\Python\Python311\Lib\site-packages\albumentations\__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.7' (you have '2.0.6'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
transform = A.Compose([
  A.HorizontalFlip(),
  A.RandomBrightnessContrast(0.2, 0.2),
  A.Rotate((10, 10)),
  A.GaussNoise(p=0.1),
  A.Blur(p=0.3),
  A.HueSaturationValue(p=0.1),
  A.Resize(640, 640, cv2.INTER_LANCZOS4, cv2.INTER_LANCZOS4)
], bbox_params=A.BboxParams(format="yolo"))

# %%
os.makedirs(final_dataset_path, exist_ok=True)
dataset_subsets_names = ["train", "val", "test"]
dataset_subsets_ratio = [0.7, 0.2, 0.1]

for name in dataset_subsets_names:
  os.makedirs(os.path.join(final_dataset_path, "images", name), exist_ok=True)
  os.makedirs(os.path.join(final_dataset_path, "labels", name), exist_ok=True)

missed_count = 0
processed_count = 0

subsets_images_count = {
  "train": 0,
  "val": 0,
  "test": 0
}

images_paths = glob(os.path.join(old_images_path, "**/*.PNG"))
random.shuffle(images_paths)

for image_path in images_paths:
  img = cv2.imread(image_path)
  
  bbox_path = image_path.replace("old-images", "old-bboxes").replace(".PNG", ".txt")
  
  bboxes = []
  class_labels = []
  try:
    with open(bbox_path, "r") as file:
      for line in file:
        cols = line.strip().split()
        class_labels.append(int(cols[0]))
        bboxes.append(np.array(list(map(lambda x: max(float(x), 0), cols[1:]))))
  except:
    print(f"Missed {image_path} because it has no bboxes")
    missed_count += 1
    continue
  
  subset = dataset_subsets_ratio[0]
  p = random.random()
  a = 0
  for i in range(len(dataset_subsets_ratio)):
    a += dataset_subsets_ratio[i]
    if (p < a):
      subset = dataset_subsets_names[i]
      break

  try:
    for _ in range(augmentations_count):
      aug_result = transform(image=img, bboxes=bboxes, class_labels=class_labels)
      aug_image = aug_result["image"]
      aug_bboxes = aug_result["bboxes"]
      
      uuid = uuid4().hex
      
      cv2.imwrite(os.path.join(final_dataset_path, "images", subset, f"{uuid}.PNG"), aug_image)
      
      with open(os.path.join(final_dataset_path, "labels", subset, f"{uuid}.txt"), "w") as file:
        for bbox, class_id in zip(aug_bboxes, class_labels):
          file.write(f"{class_id} {' '.join(map(str, bbox))}\n")
      subsets_images_count[subset] += 1
  except Exception as e:
    print(f"Error creating bboxes {image_path}: {e}")
    missed_count += 1
    continue
    
  processed_count += 1
  
print(f"Processed {processed_count} images, missed {missed_count} images")
print(f"Train: {subsets_images_count['train']}\nVal: {subsets_images_count['val']}\nTest: {subsets_images_count['test']}")
# Out:
# Missed ./datasets/old-images\p3\frame_000010.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000466.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000025.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000278.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p2\frame_001195.PNG: Expected y_min for bbox [ 7.4530482e-02 -4.7683716e-07  9.9751151e-01  8.5516649e-01] to be in the range [0.0, 1.0], got -4.76837158203125e-07.
# Missed ./datasets/old-images\p4\frame_000247.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000146.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000229.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000018.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000442.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000202.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000142.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000196.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000255.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000391.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000969.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000174.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000060.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000948.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000343.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000175.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000205.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000884.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000361.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000079.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000086.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000145.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000619.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000051.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000779.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000238.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000590.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000265.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000437.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000933.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000147.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000451.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000046.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000783.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000249.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000081.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000076.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000261.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000419.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000095.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000484.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000300.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000196.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000870.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000781.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_001097.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000441.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000028.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000535.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000768.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000019.PNG: Expected y_min for bbox [ 4.2079985e-03 -4.7683716e-07  1.0000000e+00  9.5938849e-01] to be in the range [0.0, 1.0], got -4.76837158203125e-07.
# Missed ./datasets/old-images\p3\frame_000021.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000600.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000380.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000872.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000080.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000256.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000461.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000066.PNG: Expected y_min for bbox [ 1.4359951e-03 -5.0663948e-07  1.0000000e+00  9.9141645e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000859.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000400.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000089.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000396.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000297.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000468.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000938.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000291.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000937.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000067.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000282.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000032.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000079.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000146.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000810.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000337.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000855.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000676.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000975.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000256.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000214.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000744.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000118.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000209.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000538.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000172.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000464.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000340.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000137.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000457.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000288.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000269.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000335.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000218.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000392.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000429.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000595.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000352.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000529.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000636.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000918.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000104.PNG: Expected y_min for bbox [ 5.0663948e-07 -5.0663948e-07  9.9886155e-01  9.9066651e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p3\frame_000507.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000945.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000291.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000327.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000232.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000287.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000065.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000747.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000866.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000296.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000369.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000023.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000833.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000099.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000443.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000662.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000647.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000230.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000561.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000242.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000072.PNG: Expected y_min for bbox [ 7.4246526e-04 -5.0663948e-07  9.9999952e-01  9.9538851e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p3\frame_000182.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000454.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000551.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000185.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000804.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000582.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000039.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000470.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000834.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000981.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000784.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000597.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000831.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000210.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000894.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p2\frame_001179.PNG: Expected y_min for bbox [ 3.0751020e-02 -5.0663948e-07  9.6995306e-01  9.1791654e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000843.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000614.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000540.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000432.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000788.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000440.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000373.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000068.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000114.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000751.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000299.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000212.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000497.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000037.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000246.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000110.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000422.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000276.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000129.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000374.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000071.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000812.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000087.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000455.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000609.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000186.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000451.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000264.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000378.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000774.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000017.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000270.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000390.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000237.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000145.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000033.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000082.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000946.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000176.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000094.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000210.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000176.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000264.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000468.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000272.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000867.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000424.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000041.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000403.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000187.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000431.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000080.PNG: Expected y_min for bbox [ 0.0000000e+00 -4.7683716e-07  9.9994999e-01  9.9963850e-01] to be in the range [0.0, 1.0], got -4.76837158203125e-07.
# Missed ./datasets/old-images\p3\frame_000564.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000019.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000042.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000008.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000641.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000074.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000900.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000545.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000043.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000849.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000004.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000057.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000889.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000448.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000411.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000305.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000283.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000530.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000179.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000091.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000469.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000797.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000181.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000364.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000013.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000537.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000307.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000802.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000415.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000260.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000279.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000869.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000832.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000953.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000178.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000100.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000594.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000280.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000154.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000200.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000423.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000222.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000200.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000072.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000064.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000569.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000436.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000403.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000786.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000670.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000088.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000985.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000904.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000024.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000456.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000110.PNG: Expected y_min for bbox [ 0.0000000e+00 -5.0663948e-07  9.9856400e-01  9.8841655e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000850.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000027.PNG: Expected y_min for bbox [ 5.6439936e-03 -5.0663948e-07  1.0000000e+00  9.6566653e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000791.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000049.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000566.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000417.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000363.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000479.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000533.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000433.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000360.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000252.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000258.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000281.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000367.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000119.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000157.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000103.PNG: Expected x_min for bbox [-5.0663948e-07  0.0000000e+00  9.9891055e-01  9.9105603e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000929.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000471.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000422.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000312.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000634.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000756.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000476.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000852.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000148.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000047.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000393.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000520.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000301.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000402.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000407.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000916.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000865.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000760.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000462.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000084.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000197.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000206.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000266.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000120.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000847.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000338.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000216.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p2\frame_001193.PNG: Expected y_min for bbox [ 7.6808006e-02 -4.7683716e-07  9.9875605e-01  8.5237449e-01] to be in the range [0.0, 1.0], got -4.76837158203125e-07.
# Missed ./datasets/old-images\p3\frame_000266.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000275.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000074.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000543.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000542.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000230.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000418.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000231.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000192.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000950.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000322.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000431.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000924.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000942.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000295.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000154.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000563.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000351.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000466.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000129.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000958.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000185.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000343.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000482.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000092.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000124.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000416.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000044.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000427.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000825.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000181.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000038.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000496.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000769.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000574.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000821.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000627.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000796.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000358.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000216.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000310.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000227.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000460.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000606.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000290.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000952.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000158.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000489.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000289.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000972.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000144.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000120.PNG: Expected x_min for bbox [-5.066395e-07  0.000000e+00  9.981185e-01  9.385000e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p1\frame_000476.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000901.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000593.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000011.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000984.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000402.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000179.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000837.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000654.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000385.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000487.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000163.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000798.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000386.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000632.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000085.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000121.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000376.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000571.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000449.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000427.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000061.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000225.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000108.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000099.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000579.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000029.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000135.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000189.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000517.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000134.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000331.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000092.PNG: Expected y_min for bbox [ 0.000000e+00 -5.066395e-07  9.994060e-01  9.951385e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000965.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000270.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000527.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000485.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000817.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000982.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000826.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000805.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000803.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_001098.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000052.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000661.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000618.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000838.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000773.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000878.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000132.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000318.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000141.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000055.PNG: Expected y_min for bbox [ 2.624005e-03 -5.066395e-07  1.000000e+00  9.841385e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p3\frame_000667.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000310.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000882.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000329.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000122.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000169.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000340.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000298.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000325.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000288.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000482.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000020.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000170.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000267.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000528.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000771.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000936.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000581.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000027.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000827.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000967.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000300.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000102.PNG: Expected y_min for bbox [ 0.0000000e+00 -5.0663948e-07  9.9896002e-01  9.9141645e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p1\frame_000404.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000393.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000439.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000944.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000108.PNG: Expected y_min for bbox [ 5.0663948e-07 -4.7683716e-07  9.9866354e-01  9.8916650e-01] to be in the range [0.0, 1.0], got -4.76837158203125e-07.
# Missed ./datasets/old-images\p2\frame_000879.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000111.PNG: Expected x_min for bbox [-5.0663948e-07  0.0000000e+00  9.9851453e-01  9.8805600e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p3\frame_000349.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000397.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000503.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000377.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000011.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000047.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000509.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000164.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000282.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000898.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000570.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000015.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000283.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000150.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000845.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000233.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000591.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000381.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000790.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000397.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000578.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000436.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000940.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000058.PNG: Expected y_min for bbox [ 2.2774935e-03 -5.0663948e-07  1.0000005e+00  9.8613846e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000204.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000475.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000487.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000430.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000469.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000313.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000104.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000278.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000311.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000921.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000308.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000259.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000335.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000007.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000090.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000093.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000822.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000242.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000617.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000156.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000153.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000765.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000003.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000616.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000076.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000015.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000478.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000488.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000477.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000877.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000228.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000371.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000391.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000318.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000622.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000084.PNG: Expected y_min for bbox [ 0.0000000e+00 -5.0663948e-07  9.9975199e-01  9.9813855e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p3\frame_000254.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000014.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000366.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000156.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000223.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000412.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000976.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000269.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000258.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000409.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000610.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000780.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000162.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000980.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000094.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000184.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000785.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000222.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000037.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000350.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000332.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000605.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000018.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000383.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000293.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000132.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000573.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000096.PNG: Expected y_min for bbox [ 0.000000e+00 -5.066395e-07  9.992080e-01  9.936665e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p1\frame_000474.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000856.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000510.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000040.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000394.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000927.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000070.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000296.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000097.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000168.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000307.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000068.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000308.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000306.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_001104.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000065.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000319.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_001103.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000031.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000572.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000809.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000753.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000341.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000183.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000607.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000016.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000499.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000519.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000913.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000978.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000660.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000031.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000093.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000083.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000083.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000394.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000115.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000263.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000868.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000125.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000968.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000341.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000401.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000392.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000445.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000189.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000191.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000030.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000173.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000304.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000098.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000023.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000923.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000191.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000484.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000203.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000120.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000787.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000623.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000115.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000758.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000608.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000166.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000277.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000333.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000285.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000142.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000835.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000979.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000435.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000316.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000122.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000116.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000399.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000766.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000064.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000518.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000311.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000009.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000750.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000250.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000095.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000321.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000446.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000888.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000199.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000030.PNG: Expected y_min for bbox [ 5.3464770e-03 -5.0663948e-07  9.9999946e-01  9.6763849e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p3\frame_000274.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000491.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000131.PNG because it has no bboxes
# ...
# Missed ./datasets/old-images\p1\frame_000426.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000138.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000504.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000195.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000604.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000180.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000091.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000971.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000557.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000214.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000587.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000025.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000197.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000858.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000814.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000544.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000126.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000915.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000432.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000649.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000281.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000009.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000174.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000224.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000767.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000672.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000433.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000254.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000365.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000303.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000055.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000286.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000467.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000447.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000263.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000013.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000457.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000043.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000897.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000549.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000321.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000472.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000240.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000059.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000000.PNG: Expected y_min for bbox [ 0.0000000e+00 -5.0663948e-07  1.0000000e+00  9.4416654e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000049.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000006.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000178.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000206.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000813.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000752.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000522.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000505.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000314.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000746.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000244.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000439.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000917.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000058.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000221.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000511.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000028.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000925.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000966.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000090.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_001100.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000465.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000959.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000534.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000625.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000532.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000226.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000063.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000556.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000097.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000458.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000227.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000930.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000163.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000276.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000671.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000271.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000860.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000886.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000085.PNG: Expected x_min for bbox [-5.0663948e-07  0.0000000e+00  9.9970245e-01  9.9774998e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p3\frame_000294.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000445.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000221.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000188.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000460.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000891.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000134.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000745.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000208.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000454.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000525.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000500.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000039.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000478.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000208.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000201.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000602.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000941.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000473.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000062.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000673.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000429.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000201.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000413.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000034.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000152.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000063.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000213.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000885.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000326.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000456.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000124.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000322.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000914.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000815.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000395.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000977.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000305.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000415.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000406.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000903.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000398.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000883.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000424.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000910.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000149.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000328.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000416.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000603.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000633.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000630.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000644.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000795.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000473.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000902.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000928.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000297.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000770.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000755.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000140.PNG because it has no bboxes
# Error creating bboxes ./datasets/old-images\p4\frame_000038.PNG: Expected y_min for bbox [ 4.4555068e-03 -5.0663948e-07  1.0000005e+00  9.7291648e-01] to be in the range [0.0, 1.0], got -5.066394805908203e-07.
# Missed ./datasets/old-images\p2\frame_000840.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000876.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000437.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000207.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000203.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000017.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000252.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000280.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000932.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000420.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000223.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000101.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000575.PNG because it has no bboxes
# Missed ./datasets/old-images\p4\frame_000285.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000069.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000447.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000207.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000875.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000041.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000084.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000485.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000596.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000939.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000026.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000330.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000128.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000139.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000957.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000114.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000138.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000162.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000512.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000078.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000421.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000007.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000492.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000459.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000113.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000567.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000225.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_001096.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000471.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000615.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000006.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000030.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000052.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000547.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000531.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000187.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000035.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000234.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000382.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000651.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000104.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000453.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000555.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000309.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000375.PNG because it has no bboxes
# Missed ./datasets/old-images\p2\frame_000789.PNG because it has no bboxes
# Missed ./datasets/old-images\p1\frame_000411.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000674.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000669.PNG because it has no bboxes
# Missed ./datasets/old-images\p3\frame_000240.PNG because it has no bboxes
# Processed 2109 images, missed 1411 images
# Train: 7220
# Val: 2165
# Test: 1160
